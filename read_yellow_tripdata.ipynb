# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as pl
import seaborn as sns
default="yt_2020_01.parquet"
file_name = (input("Type the file name (Must be in ./data/raw/<file_name> dir): ") != "" or default )
yt_df = pd.read_parquet("./data/raw/"+file_name)
default_prefix=default.split(".")[0]
default_extantion=default.split(".")[1]
yt_df.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2020-01-01 00:28:15   2020-01-01 00:33:03              1.0
# 1         1  2020-01-01 00:35:39   2020-01-01 00:43:04              1.0
# 2         1  2020-01-01 00:47:41   2020-01-01 00:53:52              1.0
# 3         1  2020-01-01 00:55:23   2020-01-01 01:00:14              1.0
# 4         2  2020-01-01 00:01:58   2020-01-01 00:04:16              1.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0            1.2         1.0                  N           238           239
# 1            1.2         1.0                  N           239           238
# 2            0.6         1.0                  N           238           238
# 3            0.8         1.0                  N           238           151
# 4            0.0         1.0                  N           193           193
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# ...

# %%
yt_df.info()

# %%
yt_df.shape

# %%
yt_df["passenger_count"].max()

# %%
yt_df["trip_distance"].max()

# %%
yt_df["fare_amount"].min()

# %%
yt_df["fare_amount"].max()

# %%
yt_df["extra"].min()

# %%
yt_df["extra"].max()

# %%
yt_df["mta_tax"].min()

# %%
yt_df["mta_tax"].max()

# %%
yt_df["improvement_surcharge"].min()

# %%
yt_df["improvement_surcharge"].max()

# %%
yt_df["improvement_surcharge"].mean()

# %%
yt_df["tip_amount"].min()

# %%
yt_df["tip_amount"].max()

# %%
yt_df["tolls_amount"].min()

# %%
yt_df["tolls_amount"].max()

# %%
yt_df["total_amount"].min()

# %%
yt_df["total_amount"].max()

# %%
yt_df["congestion_surcharge"].min()

# %%
yt_df["congestion_surcharge"].max()

# %%
yt_df["airport_fee"].min()

# %%
yt_df["airport_fee"].max()

# %%
sns.heatmap(yt_df.isnull(), cbar=False)
pl.savefig('./data/out/'+default_prefix+'_nulls_values_for_each_colum.png',pad_inches=0.4,
bbox_inches = 'tight')

# %%
yt_df[yt_df.duplicated()]
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 6346641         2  2020-01-06 00:13:00   2020-01-06 00:32:00              NaN
# 6346643         2  2020-01-06 00:08:00   2020-01-06 00:22:00              NaN
# 6346645         2  2020-01-06 00:40:00   2020-01-06 01:12:00              NaN
# 6346647         2  2020-01-06 00:21:53   2020-01-06 00:45:27              NaN
# 6346649         2  2020-01-06 00:11:19   2020-01-06 00:41:09              NaN
# ...           ...                  ...                   ...              ...
# 6372544         2  2020-01-12 23:07:00   2020-01-12 23:19:00              NaN
# 6372546         2  2020-01-12 23:19:00   2020-01-12 23:38:00              NaN
# 6372548         2  2020-01-12 23:25:00   2020-01-12 23:56:00              NaN
# 6372550         2  2020-01-12 23:29:22   2020-01-12 23:45:44              NaN
# 6372552         2  2020-01-12 23:35:00   2020-01-13 00:02:00              NaN
#
# ...

# %%
a = yt_df.iloc[6372546]["PULocationID"]
b = yt_df.iloc[6372546]["DOLocationID"]
c = yt_df.iloc[6372546]["trip_distance"]

yt_df.loc[ (yt_df["PULocationID"] == a) & (yt_df["DOLocationID"] == b) & (yt_df["trip_distance"] == c)]
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 6372545         2  2020-01-12 23:19:00   2020-01-12 23:38:00              NaN
# 6372546         2  2020-01-12 23:19:00   2020-01-12 23:38:00              NaN
#
#          trip_distance  RatecodeID store_and_fwd_flag  PULocationID  \
# 6372545           7.99         NaN               None           242
# 6372546           7.99         NaN               None           242
#
#          DOLocationID  payment_type  fare_amount  extra  mta_tax  tip_amount  \
# 6372545            42             0        25.88   2.75      0.5         0.0
# 6372546            42             0        25.88   2.75      0.5         0.0
#
#          tolls_amount  improvement_surcharge  total_amount  \
# 6372545           0.0                    0.3         29.43
# 6372546           0.0                    0.3         29.43
#
#          congestion_surcharge airport_fee
# 6372545                   NaN        None
# ...

# %%
yt_df.drop_duplicates(inplace=True)

# %%
yt_df.to_csv('./data/interim/yt_2020_01.csv')

# %%
yt_df = pd.read_csv('./data/interim/yt_2020_01.csv', usecols=["tpep_pickup_datetime","tpep_dropoff_datetime","passenger_count","trip_distance","PULocationID","DOLocationID","payment_type","fare_amount","congestion_surcharge"])

# %%
yt_df.to_csv('./data/interim/yt_with_less_col_2020_01.csv')

# %%
#Lets change tpep_pickup_datetime  from  datetime64[ns] to int64
yt_df["tpep_pickup_datetime"] = yt_df["tpep_pickup_datetime"].apply(lambda x: pd.Timestamp(x)).astype('int64') // 10**9
# Lets do the same form tpep_dropoff_datetime
yt_df["tpep_dropoff_datetime"] = yt_df["tpep_dropoff_datetime"].apply(lambda x: pd.Timestamp(x)).astype('int64') // 10**9

# %%
yt_df.to_csv('./data/interim/yt_with_less_col_2020_01.csv')
